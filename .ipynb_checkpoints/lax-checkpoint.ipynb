# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
df = pd.read_csv('/Users/charlesvidrine/data/flight_traffic.csv') 
df.head()
# Out:
#    year  month  day airline_id origin_airport destination_airport  \
# 0  2017      1   17         AA            CLT                 PHX
# 1  2017      1   18         AA            CLT                 PHX
# 2  2017      1   19         AA            CLT                 PHX
# 3  2017      1   20         AA            CLT                 PHX
# 4  2017      1   21         AA            CLT                 PHX
#
#    scheduled_departure  actual_departure  taxi_out  wheels_off  \
# 0                 1619            1616.0      17.0      1633.0
# 1                 1619            1614.0      13.0      1627.0
# 2                 1619            1611.0      17.0      1628.0
# 3                 1619            1656.0      18.0      1714.0
# 4                 1619            1632.0      17.0      1649.0
#
#         ...        cancelled  diverted  scheduled_elapsed  actual_elapsed  \
# 0       ...              0.0       0.0              277.0           266.0
# 1       ...              0.0       0.0              277.0           247.0
# 2       ...              0.0       0.0              277.0           255.0
# 3       ...              0.0       0.0              277.0           273.0
# 4       ...              0.0       0.0              277.0           266.0
#
#    distance  airline_delay  weather_delay  air_system_delay  security_delay  \
# 0    1773.0            NaN            NaN               NaN             NaN
# 1    1773.0            NaN            NaN               NaN             NaN
# 2    1773.0            NaN            NaN               NaN             NaN
# 3    1773.0           33.0            0.0               0.0             0.0
# 4    1773.0            NaN            NaN               NaN             NaN
#
#    aircraft_delay
# 0             NaN
# 1             NaN
# 2             NaN
# 3             0.0
# 4             NaN
#
# [5 rows x 24 columns]

# %%
def convertDateToMinutes(t):
    t = int(t)
    hours = (t/100) % 100
    minutes = t % 100
    return 60*hours + minutes
def getTimeDifference(t1, t2):
    totalMin = 24*60
    t1 = convertDateToMinutes(t1)
    t2 = convertDateToMinutes(t2)
    if t1 > t2 and t1 - t2 < 60: # early departure
        return t2 - t1
    return (t2 - t1) % totalMin

# %%
print getTimeDifference(510, 1510)
print getTimeDifference(2230, 130)
print getTimeDifference(600, 555)
# Out:
# 600
# 180
# -5

# %%
lax_df = df.loc[df['origin_airport'] == 'JFK']
print "JFK", lax_df.shape
lax_df = lax_df[lax_df['scheduled_departure'].notnull()]
lax_df = lax_df[lax_df['actual_departure'].notnull()]
lax_df = lax_df[lax_df['scheduled_arrival'].notnull()]
lax_df = lax_df[lax_df['actual_arrival'].notnull()]
lax_df = lax_df[lax_df['scheduled_elapsed'].notnull()]
lax_df = lax_df[lax_df['actual_elapsed'].notnull()]
print "JFK after filter Nan", lax_df.shape
# Out:
# JFK (94454, 24)
# JFK after filter Nan (92055, 24)

# %%
lax_df.loc[:,'dep_diff'] = lax_df.apply(lambda row: getTimeDifference(row['scheduled_departure'], row['actual_departure']), axis=1)
lax_df.loc[:,'arr_diff'] = lax_df.apply(lambda row: getTimeDifference(row['scheduled_arrival'], row['actual_arrival']), axis=1)
lax_df.loc[:,'elapsed_diff'] = lax_df['actual_elapsed'] - lax_df['scheduled_elapsed']
lax_df.head()
# Out:
#       year  month  day airline_id origin_airport destination_airport  \
# 6572  2017      1    1         AA            JFK                 EGE
# 6573  2017      1    2         AA            JFK                 EGE
# 6574  2017      1    3         AA            JFK                 EGE
# 6576  2017      1    5         AA            JFK                 EGE
# 6577  2017      1    6         AA            JFK                 EGE
#
#       scheduled_departure  actual_departure  taxi_out  wheels_off  \
# 6572                 1710            1713.0      21.0      1734.0
# 6573                 1710            1901.0      26.0      1927.0
# 6574                 1710            1851.0      21.0      1912.0
# 6576                 1710            1704.0      12.0      1716.0
# 6577                 1710            1708.0      24.0      1732.0
#
#           ...       actual_elapsed  distance  airline_delay  weather_delay  \
# 6572      ...                287.0    1746.0            NaN            NaN
# 6573      ...                298.0    1746.0           11.0            0.0
# 6574      ...                293.0    1746.0            0.0            0.0
# 6576      ...                276.0    1746.0            NaN            NaN
# 6577      ...                288.0    1746.0            NaN            NaN
#
#       air_system_delay  security_delay  aircraft_delay  dep_diff  arr_diff  \
# 6572               NaN             NaN             NaN         3        -8
# 6573               0.0             0.0           100.0       111       111
# 6574               0.0             0.0            96.0       101        96
# 6576               NaN             NaN             NaN        -6       -28
# 6577               NaN             NaN             NaN        -2       -12
#
#       elapsed_diff
# 6572         -11.0
# 6573           0.0
# 6574          -5.0
# 6576         -22.0
# 6577         -10.0
#
# [5 rows x 27 columns]
